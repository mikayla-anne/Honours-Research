# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %run helper.ipynb

# %%
savdf1 = pd.read_csv('savingprobs-1.csv', names = ['t','winner'])
savdf1 = savdf(savdf1)
accum_wins(savdf1)

savdf2 = pd.read_csv('savingprobs-2.csv', names = ['t','winner'])
savdf2 = savdf(savdf2)
accum_wins(savdf2)

savdf3 = pd.read_csv('savingprobs-3.csv', names = ['t','winner'])
savdf3 = savdf(savdf3)
accum_wins(savdf3)

savdf4 = pd.read_csv('savingprobs-4.csv', names = ['t','winner'])
savdf4 = savdf(savdf4)
accum_wins(savdf4)

savdf5 = pd.read_csv('savingprobs3-1.csv', names = ['t','winner'])
savdf5 = savdf(savdf5)
accum_wins(savdf5)

# %%
avg_wins(savdf1,savdf2,savdf3,savdf4,savdf5)

# %%
checkdf1 = pd.read_csv('check-1.csv', names = ['t','action'])
checkdf1 = checkdf(checkdf1)
plotcheck(checkdf1)

checkdf2 = pd.read_csv('check-2.csv', names = ['t','action'])
checkdf2 = checkdf(checkdf2)
plotcheck(checkdf1)

checkdf3 = pd.read_csv('check-3.csv', names = ['t','action'])
checkdf3 = checkdf(checkdf3)
plotcheck(checkdf3)

checkdf4 = pd.read_csv('check-1.csv', names = ['t','action'])
checkdf4 = checkdf(checkdf4)
plotcheck(checkdf4)

checkdf5 = pd.read_csv('check3-1.csv', names = ['t','action'])
checkdf5 = checkdf(checkdf5)
plotcheck(checkdf5)
