# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %run helper.ipynb

# %%
savdf1 = pd.read_csv('savingprobsg_df3.csv', names = ['t','winner'])
savdf1 = savdf(savdf1)
accum_wins(savdf1)

savdf2 = pd.read_csv('savingprobsg_df4.csv', names = ['t','winner'])
savdf2 = savdf(savdf2)
accum_wins(savdf2)

savdf3 = pd.read_csv('savingprobsg_df41.csv', names = ['t','winner'])
savdf3 = savdf(savdf3)
accum_wins(savdf3)

savdf4 = pd.read_csv('savingprobs-t.csv', names = ['t','winner'])
savdf4 = savdf(savdf4)
accum_wins(savdf4)

# savdf5 = pd.read_csv('savingprobsg_df.csv', names = ['t','winner'])
# savdf5 = savdf(savdf5)
# accum_wins(savdf5)

# %%
avg_wins(savdf1,savdf2,savdf3,savdf4,savdf5)
